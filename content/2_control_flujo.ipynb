# %% [markdown]
# # Control de Flujo en Python - Ejercicios
#
# Este cuaderno contiene ejercicios prácticos basados en **2_control_flujo.md**.
#
# ## Estructura
#
# Este cuaderno incluye:
# - **5 ejercicios por tema** (1 resuelto + 4 adicionales)
# - **Sección de lectura de código** - Entender qué hace el código
# - **10 ejercicios de corrección** - Encontrar y arreglar errores
# - **Ayuda gradual** - Desde mucha guía hasta mínima
#
# ## Temas (delimitados estrictamente al apunte)
#
# 1. **Condicionales `if`** - Decisiones simples
# 2. **Condicionales `if-else`** - Dos caminos
# 3. **Condicionales `if-elif-else`** - Múltiples opciones
# 4. **Condiciones Anidadas** - `if` dentro de `if`
# 5. **Bucles `while`** - Repetición con condición
# 6. **Banderas de Control** - Variables para controlar flujo
# 7. **Bucles `for`** - Iteración sobre secuencias
# 8. **Control de Bucles** - `break` y `continue`
# 9. **Bucles Anidados** - Bucles dentro de bucles
# 10. **Lectura de Código** - ¿Qué hace este código?
# 11. **Corrección de Errores** - Debug de 10 programas
#
# ---

# %% [markdown]
# ## 1. Condicionales `if` Simple
#
# ### Ejercicio Resuelto: Verificación de mayoría de edad
#
# **Problema:** Verificar si una persona es mayor de edad.
#
# **Solución paso a paso:**

# %%
# Paso 1: Pedir la edad
edad = int(input("Ingresá tu edad: "))

# Paso 2: Verificar condición
if edad >= 18:
    print("Sos mayor de edad")
    print("Podés votar")

# Paso 3: El programa continúa después del if
print("Programa finalizado")

# Explicación:
# - Si edad >= 18 es True, se ejecuta el bloque indentado
# - Si es False, se salta el bloque
# - El programa siempre continúa después del if

# %% [markdown]
# ### Ejercicio 1.1: Descuento por compra (Fácil - Con guía)
#
# **Tarea:** Si una compra es mayor a $1000, mostrar "Tenés descuento".
#
# **Ayuda:**
# ```python
# monto = float(input("Monto de compra: $"))
# if monto > 1000:
#     # Tu código aquí
# ```

# %%
# Tu solución aquí

# %% [markdown]
# ### Ejercicio 1.2: Aprobado (Fácil-Medio)
#
# **Tarea:** Si una nota es >= 60, mostrar "Aprobado" y "¡Felicitaciones!".
#
# Sin ayuda de código, pero recordá:
# - Pedir la nota
# - Usar `if`
# - Indentar correctamente

# %%
# Tu solución aquí

# %% [markdown]
# ### Ejercicio 1.3: Temperatura alta (Medio)
#
# **Tarea:** Si la temperatura es > 30°C, mostrar dos mensajes:
# - "Hace calor"
# - "Recordá tomar agua"
#
# Solo una pista: ambos mensajes van dentro del mismo `if`.

# %%
# Tu solución aquí

# %% [markdown]
# ### Ejercicio 1.4: Stock bajo (Medio-Difícil)
#
# **Tarea:** Si el stock de un producto es < 5, mostrar:
# - "¡Stock bajo!"
# - "Quedan X unidades" (con el número real)
# - "Realizar pedido"
#
# Mínima ayuda.

# %%
# Tu solución aquí

# %% [markdown]
# ---
#
# ## 2. Condicionales `if-else`
#
# ### Ejercicio Resuelto: Par o impar
#
# **Problema:** Determinar si un número es par o impar.
#
# **Solución paso a paso:**

# %%
# Paso 1: Obtener número
numero = int(input("Ingresá un número: "))

# Paso 2: Verificar con módulo
if numero % 2 == 0:
    print(f"{numero} es PAR")
else:
    print(f"{numero} es IMPAR")

# Explicación:
# - Si el resto de dividir por 2 es 0 → par
# - Caso contrario → impar
# - Siempre se ejecuta UNA de las dos ramas

# %% [markdown]
# ### Ejercicio 2.1: Mayor o menor de edad (Fácil - Con guía)
#
# **Tarea:** Si edad >= 18 mostrar "Mayor de edad", sino "Menor de edad".
#
# **Ayuda:**
# ```python
# edad = int(input("Edad: "))
# if edad >= 18:
#     # ...
# else:
#     # ...
# ```

# %%
# Tu solución aquí

# %% [markdown]
# ### Ejercicio 2.2: Positivo o negativo (Fácil-Medio)
#
# **Tarea:** Determinar si un número es positivo o negativo.
#
# Recordá usar `if-else` y el operador `>=` o `<`.

# %%
# Tu solución aquí

# %% [markdown]
# ### Ejercicio 2.3: Aprobado o desaprobado (Medio)
#
# **Tarea:** Si nota >= 60 mostrar "APROBADO" y la nota, sino "DESAPROBADO" y la nota.
#
# Ejemplo salida: `"APROBADO con 75 puntos"`

# %%
# Tu solución aquí

# %% [markdown]
# ### Ejercicio 2.4: Descuento aplicado (Medio-Difícil)
#
# **Tarea:**
# - Si compra > $1000: aplicar 10% descuento y mostrar precio final
# - Sino: mostrar precio sin descuento
#
# Calculá y mostrá el monto final en ambos casos.

# %%
# Tu solución aquí

# %% [markdown]
# ---
#
# ## 3. Condicionales `if-elif-else`
#
# ### Ejercicio Resuelto: Clasificación de edad
#
# **Problema:** Clasificar según rango de edad.
#
# **Solución paso a paso:**

# %%
# Paso 1: Obtener edad
edad = int(input("Edad: "))

# Paso 2: Clasificar con if-elif-else
if edad < 13:
    print("Niño")
elif edad < 18:
    print("Adolescente")
elif edad < 65:
    print("Adulto")
else:
    print("Adulto mayor")

# Explicación:
# - Se evalúan en orden de arriba a abajo
# - Se ejecuta SOLO la primera condición verdadera
# - El else es opcional pero recomendado

# %% [markdown]
# ### Ejercicio 3.1: Semáforo (Fácil - Con guía)
#
# **Tarea:** Según el color (rojo/amarillo/verde) mostrar la acción.
#
# **Ayuda:**
# ```python
# color = input("Color del semáforo: ").lower()
# if color == "verde":
#     print("Pasar")
# elif color == "amarillo":
#     # ...
# # Completá
# ```

# %%
# Tu solución aquí

# %% [markdown]
# ### Ejercicio 3.2: Calificación con letras (Fácil-Medio)
#
# **Tarea:** Convertir nota numérica a letra:
# - 90-100: A
# - 80-89: B
# - 70-79: C
# - 60-69: D
# - < 60: F
#
# Usá `if-elif-else`.

# %%
# Tu solución aquí

# %% [markdown]
# ### Ejercicio 3.3: Categoría de IMC (Medio)
#
# **Tarea:** Clasificar IMC:
# - < 18.5: Bajo peso
# - 18.5-24.9: Normal
# - 25-29.9: Sobrepeso
# - >= 30: Obesidad
#
# Pedí peso y altura, calculá IMC y clasificá.

# %%
# Tu solución aquí

# %% [markdown]
# ### Ejercicio 3.4: Precio de entrada (Medio-Difícil)
#
# **Tarea:** Calcular precio de entrada al cine:
# - < 5 años: Gratis
# - 5-12 años: $500
# - 13-64 años: $1000
# - >= 65 años: $700 (descuento tercera edad)
#
# Pedí edad y mostrá precio a pagar.

# %%
# Tu solución aquí

# %% [markdown]
# ---
#
# ## 4. Condiciones Anidadas
#
# ### Ejercicio Resuelto: Acceso con múltiples requisitos
#
# **Problema:** Verificar edad y si tiene permiso parental.
#
# **Solución paso a paso:**

# %%
# Paso 1: Obtener datos
edad = int(input("Edad: "))
tiene_permiso = input("¿Tiene permiso parental? (si/no): ").lower()

# Paso 2: Condiciones anidadas
if edad >= 18:
    print("Acceso permitido - Mayor de edad")
else:
    # Dentro del else, otro if
    if tiene_permiso == "si":
        print("Acceso permitido - Con permiso parental")
    else:
        print("Acceso DENEGADO")

# Explicación:
# - Primer if: verifica edad
# - Si es menor, evalúa el permiso (if anidado)
# - Se puede simplificar con operadores lógicos

# %% [markdown]
# ### Ejercicio 4.1: Préstamo bancario (Fácil - Con guía)
#
# **Tarea:** Aprobar préstamo si:
# - Edad >= 21 Y
#   - Si ingreso >= 30000
#
# **Ayuda:**
# ```python
# edad = int(input("Edad: "))
# if edad >= 21:
#     ingreso = float(input("Ingreso: "))
#     if ingreso >= 30000:
#         # ...
# ```

# %%
# Tu solución aquí

# %% [markdown]
# ### Ejercicio 4.2: Descuento VIP (Fácil-Medio)
#
# **Tarea:** Aplicar descuento si:
# - Es cliente VIP Y
#   - Compra > $500: 20% descuento
#   - Sino: 10% descuento
# - Si no es VIP: sin descuento
#
# Mostrá el total con o sin descuento.

# %%
# Tu solución aquí

# %% [markdown]
# ### Ejercicio 4.3: Admisión a evento (Medio)
#
# **Tarea:** Verificar admisión:
# - Si edad >= 18: puede pasar
# - Si edad < 18:
#   - Si tiene entrada: puede pasar
#   - Sino: no puede pasar
#
# Pedí edad y si tiene entrada.

# %%
# Tu solución aquí

# %% [markdown]
# ### Ejercicio 4.4: Sistema de login (Medio-Difícil)
#
# **Tarea:** Verificar acceso:
# - Si usuario == "admin":
#   - Si password == "1234": "Acceso administrador"
#   - Sino: "Password incorrecta"
# - Si usuario == "user":
#   - Si password == "5678": "Acceso usuario"
#   - Sino: "Password incorrecta"
# - Sino: "Usuario no existe"
#
# Sin ayuda.

# %%
# Tu solución aquí

# %% [markdown]
# ---
#
# ## 5. Bucles `while`
#
# ### Ejercicio Resuelto: Contador hasta 5
#
# **Problema:** Contar de 1 a 5 usando while.
#
# **Solución paso a paso:**

# %%
# Paso 1: Inicializar contador
contador = 1

# Paso 2: Loop mientras condición sea verdadera
while contador <= 5:
    print(f"Número: {contador}")
    contador = contador + 1  # ¡IMPORTANTE! Actualizar

# Paso 3: Después del loop
print("Terminé de contar")

# Explicación:
# - Inicializar ANTES del while
# - Condición se evalúa antes de cada iteración
# - SIEMPRE actualizar la variable de control
# - Si no actualizás: loop infinito ♾️

# %% [markdown]
# ### Ejercicio 5.1: Suma acumulativa (Fácil - Con guía)
#
# **Tarea:** Sumar números del 1 al 10.
#
# **Ayuda:**
# ```python
# suma = 0
# numero = 1
# while numero <= 10:
#     suma = suma + numero
#     numero = numero + 1
# print(f"Suma total: {suma}")
# ```
#
# Ejecutá y entendé cómo funciona.

# %%
# Tu solución aquí

# %% [markdown]
# ### Ejercicio 5.2: Cuenta regresiva (Fácil-Medio)
#
# **Tarea:** Cuenta regresiva desde 10 hasta 1, luego mostrar "¡Despegue!".
#
# Recordá:
# - Inicializar en 10
# - Decrementar (restar 1)
# - Condición `>= 1`

# %%
# Tu solución aquí

# %% [markdown]
# ### Ejercicio 5.3: Validación de entrada (Medio)
#
# **Tarea:** Pedir una contraseña hasta que sea "python123".
#
# Mostrá "Contraseña incorrecta, intente de nuevo" en cada error.
# Cuando sea correcta: "Acceso concedido".

# %%
# Tu solución aquí

# %% [markdown]
# ### Ejercicio 5.4: Menú interactivo (Medio-Difícil)
#
# **Tarea:** Crear un menú que se repita hasta que elijan salir:
#
# ```
# 1. Saludar
# 2. Despedirse
# 3. Salir
# ```
#
# Según la opción, mostrar un mensaje apropiado.
# Repetir hasta que elijan 3.

# %%
# Tu solución aquí

# %% [markdown]
# ---
#
# ## 6. Banderas de Control
#
# ### Ejercicio Resuelto: Buscar número par
#
# **Problema:** Buscar el primer número par en una secuencia.
#
# **Solución paso a paso:**

# %%
# Paso 1: Inicializar bandera y contador
encontrado = False
numero = 1

# Paso 2: Buscar mientras no encontremos
while not encontrado and numero <= 10:
    if numero % 2 == 0:
        print(f"Primer par encontrado: {numero}")
        encontrado = True  # Cambiar bandera
    numero = numero + 1

# Paso 3: Verificar resultado
if not encontrado:
    print("No se encontró ningún par")

# Explicación:
# - Bandera: variable booleana para controlar el loop
# - Inicializar en False
# - Cambiar a True cuando se cumple la condición
# - El loop termina cuando la bandera es True

# %% [markdown]
# ### Ejercicio 6.1: Buscar múltiplo (Fácil - Con guía)
#
# **Tarea:** Buscar el primer múltiplo de 7 entre 1 y 50.
#
# **Ayuda:**
# ```python
# encontrado = False
# numero = 1
# while not encontrado and numero <= 50:
#     if numero % 7 == 0:
#         # ...
# ```

# %%
# Tu solución aquí

# %% [markdown]
# ### Ejercicio 6.2: Contraseña con intentos (Fácil-Medio)
#
# **Tarea:** Dar 3 intentos para ingresar "secreto".
# - Si acierta: "Acceso concedido"
# - Si agota intentos: "Bloqueado"
#
# Usá una bandera `acceso_concedido`.

# %%
# Tu solución aquí

# %% [markdown]
# ### Ejercicio 6.3: Validar edad (Medio)
#
# **Tarea:** Pedir edad hasta que sea válida (0-120).
# Máximo 5 intentos.
#
# Si es válida antes: salir con la edad.
# Si agota intentos: "Demasiados intentos inválidos".

# %%
# Tu solución aquí

# %% [markdown]
# ### Ejercicio 6.4: Juego de adivinanza simple (Medio-Difícil)
#
# **Tarea:** Adivinar un número entre 1 y 20 (definilo vos).
# - Dar pistas: "muy alto" o "muy bajo"
# - Máximo 6 intentos
# - Usar banderas apropiadas

# %%
# Tu solución aquí

# %% [markdown]
# ---
#
# ## 7. Bucles `for`
#
# ### Ejercicio Resuelto: Iterar sobre un rango
#
# **Problema:** Mostrar números del 1 al 5 usando for.
#
# **Solución paso a paso:**

# %%
# Paso 1: For con range()
for numero in range(1, 6):  # De 1 a 5 (6 no incluido)
    print(f"Número: {numero}")

# Paso 2: For con rango de 0 a n-1
print("\nDel 0 al 4:")
for i in range(5):  # De 0 a 4
    print(i)

# Paso 3: For con saltos
print("\nPares del 0 al 10:")
for i in range(0, 11, 2):  # Inicio, fin, paso
    print(i)

# Explicación:
# - range(n): de 0 a n-1
# - range(inicio, fin): de inicio a fin-1
# - range(inicio, fin, paso): con incremento personalizado
# - La variable (i, numero) toma cada valor automáticamente

# %% [markdown]
# ### Ejercicio 7.1: Tabla de multiplicar (Fácil - Con guía)
#
# **Tarea:** Mostrar la tabla del 5 (del 1 al 10).
#
# **Ayuda:**
# ```python
# numero = 5
# for i in range(1, 11):
#     resultado = numero * i
#     print(f"{numero} x {i} = {resultado}")
# ```

# %%
# Tu solución aquí

# %% [markdown]
# ### Ejercicio 7.2: Suma con for (Fácil-Medio)
#
# **Tarea:** Sumar los números del 1 al 100 usando for.
#
# Recordá:
# - Inicializar suma = 0 antes del for
# - Acumular en cada iteración

# %%
# Tu solución aquí

# %% [markdown]
# ### Ejercicio 7.3: Contar vocales (Medio)
#
# **Tarea:** Contar cuántas vocales hay en un texto.
#
# Pedí un texto y usá `for` para recorrer cada letra.
# Verificá si cada letra está en "aeiouAEIOU".

# %%
# Tu solución aquí

# %% [markdown]
# ### Ejercicio 7.4: Factorial con for (Medio-Difícil)
#
# **Tarea:** Calcular el factorial de un número.
#
# Factorial de n = 1 × 2 × 3 × ... × n
#
# Pedí el número y calculá usando for.

# %%
# Tu solución aquí

# %% [markdown]
# ---
#
# ## 8. Control de Bucles: `break` y `continue`
#
# ### Ejercicio Resuelto: Buscar con break
#
# **Problema:** Buscar la primera vocal en un texto.
#
# **Solución paso a paso:**

# %%
# Paso 1: Texto de prueba
texto = "Python es genial"

# Paso 2: Buscar con break
encontrada = False
for letra in texto:
    if letra in "aeiouAEIOU":
        print(f"Primera vocal encontrada: {letra}")
        encontrada = True
        break  # Salir del loop inmediatamente

if not encontrada:
    print("No hay vocales")

# Paso 3: Ejemplo de continue (saltar iteración)
print("\nNúmeros impares del 1 al 10:")
for i in range(1, 11):
    if i % 2 == 0:  # Si es par
        continue    # Saltar esta iteración
    print(i)  # Solo se ejecuta para impares

# Explicación:
# - break: sale del loop completamente
# - continue: salta a la siguiente iteración

# %% [markdown]
# ### Ejercicio 8.1: Salir al encontrar (Fácil - Con guía)
#
# **Tarea:** Buscar el número 7 en un rango de 1 a 20. Al encontrarlo, salir.
#
# **Ayuda:**
# ```python
# for numero in range(1, 21):
#     if numero == 7:
#         print(f"Encontré el {numero}!")
#         break
# ```

# %%
# Tu solución aquí

# %% [markdown]
# ### Ejercicio 8.2: Saltar pares (Fácil-Medio)
#
# **Tarea:** Mostrar solo números impares del 1 al 20 usando `continue`.
#
# Si el número es par, usar `continue` para saltarlo.

# %%
# Tu solución aquí

# %% [markdown]
# ### Ejercicio 8.3: Validar hasta correcto (Medio)
#
# **Tarea:** Pedir números del 1 al 5. Si ingresa uno inválido, usar `continue`.
# Si ingresa 0, salir con `break`.
#
# Mostrá los números válidos.

# %%
# Tu solución aquí

# %% [markdown]
# ### Ejercicio 8.4: Buscar palabra (Medio-Difícil)
#
# **Tarea:** Pedí palabras una por una.
# - Si ingresa "salir": usar break
# - Si la palabra tiene menos de 3 letras: usar continue (no la proceses)
# - Sino: mostrar la palabra en mayúsculas

# %%
# Tu solución aquí

# %% [markdown]
# ---
#
# ## 9. Bucles Anidados
#
# ### Ejercicio Resuelto: Tabla de multiplicar completa
#
# **Problema:** Mostrar tablas del 1 al 3.
#
# **Solución paso a paso:**

# %%
# Paso 1: Bucle externo (tabla)
for tabla in range(1, 4):  # Tablas del 1 al 3
    print(f"\n=== Tabla del {tabla} ===")
    
    # Paso 2: Bucle interno (multiplicador)
    for multiplicador in range(1, 6):  # Del 1 al 5
        resultado = tabla * multiplicador
        print(f"{tabla} x {multiplicador} = {resultado}")

# Explicación:
# - El bucle externo controla qué tabla
# - El bucle interno hace las multiplicaciones
# - Por cada iteración del externo, el interno se ejecuta completamente
# - Total iteraciones: 3 × 5 = 15

# %% [markdown]
# ### Ejercicio 9.1: Rectángulo de asteriscos (Fácil - Con guía)
#
# **Tarea:** Dibujar un rectángulo de 4 filas × 6 columnas de asteriscos.
#
# **Ayuda:**
# ```python
# for fila in range(4):
#     for columna in range(6):
#         print("*", end="")
#     print()  # Nueva línea
# ```

# %%
# Tu solución aquí

# %% [markdown]
# ### Ejercicio 9.2: Cuadrado de números (Fácil-Medio)
#
# **Tarea:** Crear un cuadrado de 5×5 mostrando el número de fila.
#
# Ejemplo:
# ```
# 11111
# 22222
# 33333
# 44444
# 55555
# ```

# %%
# Tu solución aquí

# %% [markdown]
# ### Ejercicio 9.3: Triángulo de números (Medio)
#
# **Tarea:** Crear un triángulo:
# ```
# 1
# 12
# 123
# 1234
# 12345
# ```
#
# Pista: El bucle interno depende del externo.

# %%
# Tu solución aquí

# %% [markdown]
# ### Ejercicio 9.4: Tabla de multiplicar elegante (Medio-Difícil)
#
# **Tarea:** Mostrar tablas del 1 al 5, del 1 al 10, con formato:
#
# ```
# TABLA DEL 1
# -----------
# 1 x 1 = 1
# 1 x 2 = 2
# ...
# ```
#
# Sin ayuda.

# %%
# Tu solución aquí

# %% [markdown]
# ---
#
# ## 10. Lectura de Código
#
# En esta sección, **NO ejecutes el código inmediatamente**. Primero leé y determiná qué hace.
#
# ### Instrucciones:
# 1. Leé el código cuidadosamente
# 2. Intentá predecir la salida en un comentario
# 3. Recién después ejecutá para verificar
#
# ### Código 10.1: ¿Qué imprime? (Fácil)

# %%
# ¿Qué imprime este código?
# Tu predicción aquí antes de ejecutar:

x = 10
if x > 5:
    print("Grande")
if x > 15:
    print("Muy grande")
print("Fin")

# Ejecutá y verificá tu predicción

# %% [markdown]
# ### Código 10.2: ¿Qué hace este while? (Fácil-Medio)

# %%
# ¿Qué hace este código? Describí en un comentario:

contador = 5
suma = 0
while contador > 0:
    suma = suma + contador
    contador = contador - 1
print(suma)

# Tu respuesta: Este código...
# Ejecutá y verificá

# %% [markdown]
# ### Código 10.3: ¿Cuántas veces se ejecuta? (Medio)

# %%
# ¿Cuántas veces se imprime "Hola"?
# Tu predicción:

for i in range(3):
    for j in range(2):
        print("Hola")

# ¿Por qué ese número?
# Ejecutá y verificá

# %% [markdown]
# ### Código 10.4: ¿Qué números muestra? (Medio)

# %%
# ¿Qué números imprime? Escribí la lista:
# Tu predicción: [...]

for i in range(1, 10):
    if i % 3 == 0:
        continue
    print(i)

# Ejecutá y verificá

# %% [markdown]
# ### Código 10.5: ¿Cuál es la salida? (Medio-Difícil)

# %%
# Predecí la salida completa:

n = 1
while n <= 5:
    if n == 3:
        n += 1
        continue
    print(n)
    n += 1

# Tu predicción de salida:
# Ejecutá y verificá

# %% [markdown]
# ### Código 10.6: ¿Qué dibuja? (Medio-Difícil)

# %%
# ¿Qué patrón forma?

for i in range(1, 5):
    print("*" * i)

# Dibujá el resultado esperado en comentarios
# Ejecutá y verificá

# %% [markdown]
# ### Código 10.7: Análisis completo (Difícil)

# %%
# Analizá este código:
# 1. ¿Qué hace?
# 2. ¿Qué imprime?
# 3. ¿Cuántas iteraciones?

encontrado = False
for numero in range(2, 20):
    if numero % 5 == 0 and numero % 3 == 0:
        print(f"Encontrado: {numero}")
        encontrado = True
        break

if not encontrado:
    print("No encontrado")

# Tus respuestas:
# 1. 
# 2. 
# 3. 
# Ejecutá y verificá

# %% [markdown]
# ---
#
# ## 11. Corrección de Errores
#
# Cada código tiene **errores** que debés encontrar y corregir.
#
# ### Instrucciones:
# 1. Leé el código y el resultado esperado
# 2. Identificá el/los error/es
# 3. Corregí el código
# 4. Verificá que funcione
#
# ---
#
# ### Error 11.1: Comparación incorrecta (Fácil - Con pista)
#
# **Resultado esperado:** Si edad >= 18, mostrar "Adulto"
#
# **Pista:** Revisá el operador de comparación

# %%
# Código con error:
edad = 20
if edad = 18:
    print("Adulto")

# Corregí el error aquí:

# %% [markdown]
# ### Error 11.2: Indentación (Fácil - Con pista)
#
# **Resultado esperado:** Sumar números del 1 al 5 = 15
#
# **Pista:** Revisá la indentación

# %%
# Código con error:
suma = 0
for i in range(1, 6):
suma = suma + i
print(suma)

# Corregí el error aquí:

# %% [markdown]
# ### Error 11.3: Loop infinito (Fácil-Medio - Con pista)
#
# **Resultado esperado:** Contar de 1 a 5 y terminar
#
# **Pista:** ¿Se actualiza el contador?

# %%
# Código con error:
contador = 1
while contador <= 5:
    print(contador)

# Corregí el error aquí:

# %% [markdown]
# ### Error 11.4: Condición incorrecta (Fácil-Medio)
#
# **Resultado esperado:** Mostrar números impares del 1 al 10
#
# **Sin pista**

# %%
# Código con error:
for i in range(1, 11):
    if i % 2 == 0:
        print(i)

# Corregí el error aquí:

# %% [markdown]
# ### Error 11.5: Variable no inicializada (Medio)
#
# **Resultado esperado:** Calcular factorial de 5 = 120
#
# **Sin pista**

# %%
# Código con error:
n = 5
for i in range(1, n + 1):
    factorial = factorial * i
print(factorial)

# Corregí el error aquí:

# %% [markdown]
# ### Error 11.6: Rango incorrecto (Medio)
#
# **Resultado esperado:** Mostrar números del 1 al 10 (inclusive)
#
# **Sin pista**

# %%
# Código con error:
for i in range(1, 10):
    print(i)

# Corregí el error aquí:

# %% [markdown]
# ### Error 11.7: Break mal ubicado (Medio)
#
# **Resultado esperado:** Buscar el primer múltiplo de 7 menor que 50
#
# **Sin pista**

# %%
# Código con error:
for numero in range(1, 50):
    break
    if numero % 7 == 0:
        print(f"Encontrado: {numero}")

# Corregí el error aquí:

# %% [markdown]
# ### Error 11.8: Lógica invertida (Medio-Difícil)
#
# **Resultado esperado:** Mostrar "Par" si es par, "Impar" si es impar
#
# **Sin pista**

# %%
# Código con error:
numero = 7
if numero % 2 == 0:
    print("Impar")
else:
    print("Par")

# Corregí el error aquí:

# %% [markdown]
# ### Error 11.9: Múltiples errores (Difícil)
#
# **Resultado esperado:** Contar vocales en "Python" = 1
#
# **Sin pista - Hay 2 errores**

# %%
# Código con error:
texto = "Python"
contador = 0
for letra in range(texto):
    if letra in "aeiou":
    contador = contador + 1
print(contador)

# Corregí los errores aquí:

# %% [markdown]
# ### Error 11.10: Lógica compleja (Muy difícil)
#
# **Resultado esperado:** Encontrar números del 1 al 20 que sean:
# - Múltiplos de 3 O múltiplos de 5
# - Pero NO múltiplos de 3 Y 5 al mismo tiempo
#
# Resultado: 3, 5, 6, 9, 10, 12, 18, 20
#
# **Sin pista - Hay 3 errores**

# %%
# Código con error:
for n in range(1, 21):
    if n % 3 == 0 and n % 5 == 0:
        if not (n % 3 == 0 or n % 5 == 0):
            print(n)

# Corregí los errores aquí:

# %% [markdown]
# ---
#
# ## Conclusión
#
# ¡Felicitaciones por completar los ejercicios de Control de Flujo! 🎉
#
# ### Has practicado:
#
# ✅ **Condicionales:**
# - `if` simple - Decisiones básicas
# - `if-else` - Dos caminos
# - `if-elif-else` - Múltiples opciones
# - Condiciones anidadas
#
# ✅ **Bucles:**
# - `while` - Repetición con condición
# - `for` - Iteración sobre secuencias
# - `break` y `continue` - Control de flujo
# - Bucles anidados - Iteraciones múltiples
#
# ✅ **Habilidades especiales:**
# - Banderas de control
# - Lectura de código
# - Corrección de errores
#
# ### Estadísticas del cuaderno:
#
# - **9 temas principales** con ejercicios
# - **36 ejercicios de práctica** (9 resueltos + 27 adicionales)
# - **7 ejercicios de lectura** de código
# - **10 ejercicios de corrección** de errores
# - **Total: 53 ejercicios**
#
# ### Próximos pasos:
#
# 1. **Revisá tus soluciones** - ¿Podés mejorarlas?
# 2. **Resolvé los ejercicios del apunte** - 2_control_flujo.md tiene más
# 3. **Practicá patrones comunes** - Acumuladores, contadores, validación
# 4. **Combiná conceptos** - Usa todo junto en problemas más grandes
# 5. **Avanzá al siguiente capítulo** - Cuando domines control de flujo
#
# ### Recursos adicionales:
#
# - `2_control_flujo.md` - Apunte teórico completo
# - `notebooks_control_flujo.ipynb` - Material complementario
# - Ejercicios del apunte con soluciones
#
# ### Recordá:
#
# > **El control de flujo es el cerebro de tus programas.**
# >
# > Sin condicionales y bucles, tu código solo puede hacer una cosa de una manera.
# > Con ellos, ¡puede resolver millones de problemas diferentes!
#
# ---
#
# ### Checklist de dominio:
#
# Marcá lo que ya podés hacer sin ayuda:
#
# - [ ] Escribir condicionales if/elif/else correctamente
# - [ ] Usar operadores lógicos para condiciones complejas
# - [ ] Crear bucles while que terminen correctamente
# - [ ] Usar for para iterar sobre rangos y strings
# - [ ] Implementar break y continue apropiadamente
# - [ ] Crear bucles anidados funcionales
# - [ ] Leer código y predecir su comportamiento
# - [ ] Encontrar y corregir errores comunes
# - [ ] Usar banderas para controlar flujo
# - [ ] Evitar loops infinitos
#
# **Si marcaste todo, ¡estás listo para Estructuras de Datos!** 🚀
#
# ---
#
# **¿Dudas?** Consultá el apunte `2_control_flujo.md` para explicaciones detalladas.
#
# **¿Querés más práctica?** Inventá tus propios ejercicios o modificá los existentes.
