# %% [markdown]
# # Primeros Pasos - Ejercicios de Pseudocódigo
#
# Este cuaderno contiene 15 ejercicios de dificultad creciente. Cada ejercicio presenta un problema descrito en pseudocódigo que debés implementar en Python.
#
# ## Instrucciones
#
# - Leé cuidadosamente el pseudocódigo de cada ejercicio
# - Implementá la solución en Python en la celda correspondiente
# - Probá tu código con los casos de prueba sugeridos
# - Verificá que tu solución funcione correctamente antes de continuar

# %% [markdown]
# ## Ejercicio 1: Saludo Simple
#
# Implementá el siguiente algoritmo:
#
# ```pseudocode
# algoritmo saludar
#     mostrar "¡Hola, mundo!"
# fin algoritmo
# ```
#
# **Salida esperada:** `¡Hola, mundo!`

# %%
# Tu código aquí

# %% [markdown]
# ## Ejercicio 2: Suma de Dos Números
#
# Implementá el siguiente algoritmo:
#
# ```pseudocode
# algoritmo sumar_dos_numeros
#     leer numero1
#     leer numero2
#     suma ← numero1 + numero2
#     mostrar suma
# fin algoritmo
# ```
#
# **Ejemplo:** Para `numero1 = 5` y `numero2 = 3`, la salida debe ser `8`

# %%
# Tu código aquí

# %% [markdown]
# ## Ejercicio 3: Área de un Rectángulo
#
# Implementá el siguiente algoritmo:
#
# ```pseudocode
# algoritmo calcular_area_rectangulo
#     leer base
#     leer altura
#     area ← base * altura
#     mostrar "El área del rectángulo es:", area
# fin algoritmo
# ```
#
# **Ejemplo:** Para `base = 4` y `altura = 5`, la salida debe ser `El área del rectángulo es: 20`

# %%
# Tu código aquí

# %% [markdown]
# ## Ejercicio 4: Número Par o Impar
#
# Implementá el siguiente algoritmo:
#
# ```pseudocode
# algoritmo verificar_paridad
#     leer numero
#     si numero mod 2 = 0 entonces
#         mostrar "El número es par"
#     sino
#         mostrar "El número es impar"
#     fin si
# fin algoritmo
# ```
#
# **Ejemplos:**
# - Para `numero = 8`, la salida debe ser `El número es par`
# - Para `numero = 7`, la salida debe ser `El número es impar`

# %%
# Tu código aquí

# %% [markdown]
# ## Ejercicio 5: Mayor de Tres Números
#
# Implementá el siguiente algoritmo:
#
# ```pseudocode
# algoritmo encontrar_mayor
#     leer a
#     leer b
#     leer c
#     mayor ← a
#     si b > mayor entonces
#         mayor ← b
#     fin si
#     si c > mayor entonces
#         mayor ← c
#     fin si
#     mostrar "El mayor es:", mayor
# fin algoritmo
# ```
#
# **Ejemplo:** Para `a = 5`, `b = 12`, `c = 8`, la salida debe ser `El mayor es: 12`

# %%
# Tu código aquí

# %% [markdown]
# ## Ejercicio 6: Tabla de Multiplicar
#
# Implementá el siguiente algoritmo:
#
# ```pseudocode
# algoritmo tabla_multiplicar
#     leer numero
#     i ← 1
#     mientras i ≤ 10 hacer
#         resultado ← numero * i
#         mostrar numero, "x", i, "=", resultado
#         i ← i + 1
#     fin mientras
# fin algoritmo
# ```
#
# **Ejemplo:** Para `numero = 5`, debe mostrar la tabla del 5 del 1 al 10

# %%
# Tu código aquí

# %% [markdown]
# ## Ejercicio 7: Suma de Números del 1 al N
#
# Implementá el siguiente algoritmo:
#
# ```pseudocode
# algoritmo suma_hasta_n
#     leer n
#     suma ← 0
#     i ← 1
#     mientras i ≤ n hacer
#         suma ← suma + i
#         i ← i + 1
#     fin mientras
#     mostrar "La suma es:", suma
# fin algoritmo
# ```
#
# **Ejemplo:** Para `n = 5`, la suma es 1+2+3+4+5 = 15

# %%
# Tu código aquí

# %% [markdown]
# ## Ejercicio 8: Factorial de un Número
#
# Implementá el siguiente algoritmo:
#
# ```pseudocode
# algoritmo calcular_factorial
#     leer n
#     factorial ← 1
#     i ← 1
#     mientras i ≤ n hacer
#         factorial ← factorial * i
#         i ← i + 1
#     fin mientras
#     mostrar "El factorial de", n, "es:", factorial
# fin algoritmo
# ```
#
# **Ejemplo:** Para `n = 5`, el factorial es 5! = 120

# %%
# Tu código aquí

# %% [markdown]
# ## Ejercicio 9: Contar Dígitos de un Número
#
# Implementá el siguiente algoritmo:
#
# ```pseudocode
# algoritmo contar_digitos
#     leer numero
#     contador ← 0
#     mientras numero > 0 hacer
#         numero ← numero div 10
#         contador ← contador + 1
#     fin mientras
#     mostrar "Cantidad de dígitos:", contador
# fin algoritmo
# ```
#
# **Ejemplo:** Para `numero = 12345`, la salida debe ser `Cantidad de dígitos: 5`

# %%
# Tu código aquí

# %% [markdown]
# ## Ejercicio 10: Números Pares hasta N
#
# Implementá el siguiente algoritmo:
#
# ```pseudocode
# algoritmo mostrar_pares
#     leer n
#     i ← 2
#     mientras i ≤ n hacer
#         mostrar i
#         i ← i + 2
#     fin mientras
# fin algoritmo
# ```
#
# **Ejemplo:** Para `n = 10`, debe mostrar: 2, 4, 6, 8, 10

# %%
# Tu código aquí

# %% [markdown]
# ## Ejercicio 11: Invertir un Número
#
# Implementá el siguiente algoritmo:
#
# ```pseudocode
# algoritmo invertir_numero
#     leer numero
#     invertido ← 0
#     mientras numero > 0 hacer
#         digito ← numero mod 10
#         invertido ← invertido * 10 + digito
#         numero ← numero div 10
#     fin mientras
#     mostrar "Número invertido:", invertido
# fin algoritmo
# ```
#
# **Ejemplo:** Para `numero = 1234`, la salida debe ser `Número invertido: 4321`

# %%
# Tu código aquí

# %% [markdown]
# ## Ejercicio 12: Suma de Dígitos
#
# Implementá el siguiente algoritmo:
#
# ```pseudocode
# algoritmo suma_digitos
#     leer numero
#     suma ← 0
#     mientras numero > 0 hacer
#         digito ← numero mod 10
#         suma ← suma + digito
#         numero ← numero div 10
#     fin mientras
#     mostrar "Suma de dígitos:", suma
# fin algoritmo
# ```
#
# **Ejemplo:** Para `numero = 1234`, la suma es 1+2+3+4 = 10

# %%
# Tu código aquí

# %% [markdown]
# ## Ejercicio 13: Números Primos hasta N
#
# Implementá el siguiente algoritmo:
#
# ```pseudocode
# algoritmo mostrar_primos
#     leer n
#     numero ← 2
#     mientras numero ≤ n hacer
#         es_primo ← verdadero
#         divisor ← 2
#         mientras divisor < numero hacer
#             si numero mod divisor = 0 entonces
#                 es_primo ← falso
#             fin si
#             divisor ← divisor + 1
#         fin mientras
#         si es_primo entonces
#             mostrar numero
#         fin si
#         numero ← numero + 1
#     fin mientras
# fin algoritmo
# ```
#
# **Ejemplo:** Para `n = 20`, debe mostrar: 2, 3, 5, 7, 11, 13, 17, 19

# %%
# Tu código aquí

# %% [markdown]
# ## Ejercicio 14: Secuencia de Fibonacci
#
# Implementá el siguiente algoritmo:
#
# ```pseudocode
# algoritmo fibonacci
#     leer n
#     a ← 0
#     b ← 1
#     i ← 1
#     mostrar a
#     mostrar b
#     mientras i < n - 1 hacer
#         siguiente ← a + b
#         mostrar siguiente
#         a ← b
#         b ← siguiente
#         i ← i + 1
#     fin mientras
# fin algoritmo
# ```
#
# **Ejemplo:** Para `n = 8`, debe mostrar: 0, 1, 1, 2, 3, 5, 8, 13

# %%
# Tu código aquí

# %% [markdown]
# ## Ejercicio 15: Máximo Común Divisor (MCD)
#
# Implementá el siguiente algoritmo usando el método de Euclides:
#
# ```pseudocode
# algoritmo calcular_mcd
#     leer a
#     leer b
#     mientras b ≠ 0 hacer
#         resto ← a mod b
#         a ← b
#         b ← resto
#     fin mientras
#     mostrar "El MCD es:", a
# fin algoritmo
# ```
#
# **Ejemplo:** Para `a = 48` y `b = 18`, el MCD es 6

# %%
# Tu código aquí

# %% [markdown]
# ---
#
# ## ¡Felicitaciones!
#
# Has completado los 15 ejercicios de pseudocódigo. Estos ejercicios te ayudaron a:
#
# - Interpretar pseudocódigo y traducirlo a Python
# - Trabajar con estructuras de control (condicionales y lazos)
# - Manipular variables y realizar operaciones aritméticas
# - Implementar algoritmos clásicos (factorial, Fibonacci, MCD, números primos)
#
# Continuá practicando con ejercicios más complejos para fortalecer tus habilidades de programación.
