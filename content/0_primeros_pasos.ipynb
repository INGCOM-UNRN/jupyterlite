# %% [markdown]
# # Primeros Pasos en Programación - Ejercicios con Diagramas de Flujo
#
# Este cuaderno contiene ejercicios prácticos para complementar el capítulo [Primeros Pasos](https://ingcom-unrn.github.io/apunte-ingreso/primeros-pasos/).
#
# Si estás muy perdido en cómo usar esta herramienta, consulta con la [Guía Jupyterlab](https://ingcom-unrn.github.io/apunte-ingreso/a-jupyterlab/) o hacé una pregunta.
#
# Pueden modificar todo, por lo que son libres de practicar como se les ocurra ;-)
#
# ## Temas a practicar
#
# 1. **Diagramas de Flujo** - Lectura e interpretación
# 2. **Secuencias** - Pasos ordenados
# 3. **Decisiones** - Condicionales simples
# 4. **Lazos** - Repetición de acciones
# 5. **Variables** - Almacenamiento de valores
# 6. **Operaciones** - Cálculos básicos
#
# ---

# %% [markdown]
# ## Ejercicio 1: Saludo Simple
#
# Implementá el siguiente algoritmo en Python:
#
# ```mermaid
# %%{init: {'theme':'base', 'themeVariables': { 'primaryColor':'#e8f4f8','primaryTextColor':'#000','primaryBorderColor':'#3498db','lineColor':'#2c3e50','secondaryColor':'#ecf0f1','tertiaryColor':'#fff'}}}%%
# flowchart TD
#     inicio([Inicio])
#     mostrar["Mostrar 'Hola, mundo!'"]
#     fin([Fin])
#
#     inicio --> mostrar --> fin
#
#     style inicio fill:#e8f4f8,stroke:#3498db,stroke-width:3px
#     style fin fill:#e8f4f8,stroke:#3498db,stroke-width:3px
#     style mostrar fill:#d5e8f7,stroke:#2980b9,stroke-width:2px
# ```
#
# **Salida esperada:**
# ```
# Hola, mundo!
# ```

# %%
# Escribí tu código aquí

# %% [markdown]
# ## Ejercicio 2: Suma de Dos Números
#
# Implementá el siguiente algoritmo que suma dos números:
#
# ```mermaid
# %%{init: {'theme':'base', 'themeVariables': { 'primaryColor':'#e8f4f8','primaryTextColor':'#000','primaryBorderColor':'#3498db','lineColor':'#2c3e50','secondaryColor':'#ecf0f1','tertiaryColor':'#fff'}}}%%
# flowchart TD
#     inicio([Inicio])
#     leer1[/"Leer a"/]
#     leer2[/"Leer b"/]
#     calcular["suma ← a + b"]
#     mostrar[/"Mostrar suma"/]
#     fin([Fin])
#
#     inicio --> leer1 --> leer2 --> calcular --> mostrar --> fin
#
#     style inicio fill:#e8f4f8,stroke:#3498db,stroke-width:3px
#     style fin fill:#e8f4f8,stroke:#3498db,stroke-width:3px
#     style leer1 fill:#fef5e7,stroke:#f39c12,stroke-width:2px
#     style leer2 fill:#fef5e7,stroke:#f39c12,stroke-width:2px
#     style mostrar fill:#fef5e7,stroke:#f39c12,stroke-width:2px
#     style calcular fill:#d5e8f7,stroke:#2980b9,stroke-width:2px
# ```
#
# **Ejemplo de ejecución:**
# ```
# Ingresá un número: 5
# Ingresá otro número: 3
# La suma es: 8
# ```

# %%
# Escribí tu código aquí

# %% [markdown]
# ## Ejercicio 3: Par o Impar
#
# Implementá el siguiente algoritmo que determina si un número es par o impar:
#
# ```mermaid
# %%{init: {'theme':'base', 'themeVariables': { 'primaryColor':'#e8f4f8','primaryTextColor':'#000','primaryBorderColor':'#3498db','lineColor':'#2c3e50','secondaryColor':'#ecf0f1','tertiaryColor':'#fff'}}}%%
# flowchart TD
#     inicio([Inicio])
#     leer[/"Leer numero"/]
#     decision{"numero % 2 = 0"}
#     par[/"Mostrar 'Es par'"/]
#     impar[/"Mostrar 'Es impar'"/]
#     fin([Fin])
#
#     inicio --> leer --> decision
#     decision -->|Verdadero| par --> fin
#     decision -->|Falso| impar --> fin
#
#     style inicio fill:#e8f4f8,stroke:#3498db,stroke-width:3px
#     style fin fill:#e8f4f8,stroke:#3498db,stroke-width:3px
#     style leer fill:#fef5e7,stroke:#f39c12,stroke-width:2px
#     style par fill:#fef5e7,stroke:#f39c12,stroke-width:2px
#     style impar fill:#fef5e7,stroke:#f39c12,stroke-width:2px
#     style decision fill:#fadbd8,stroke:#e74c3c,stroke-width:2px
# ```
#
# **Ejemplo de ejecución:**
# ```
# Ingresá un número: 7
# Es impar
# ```

# %%
# Escribí tu código aquí

# %% [markdown]
# ## Ejercicio 4: Máximo de Dos Números
#
# Implementá el siguiente algoritmo que encuentra el mayor de dos números:
#
# ```mermaid
# %%{init: {'theme':'base', 'themeVariables': { 'primaryColor':'#e8f4f8','primaryTextColor':'#000','primaryBorderColor':'#3498db','lineColor':'#2c3e50','secondaryColor':'#ecf0f1','tertiaryColor':'#fff'}}}%%
# flowchart TD
#     inicio([Inicio])
#     leer1[/"Leer a"/]
#     leer2[/"Leer b"/]
#     decision{"a > b"}
#     asignar_a["maximo ← a"]
#     asignar_b["maximo ← b"]
#     mostrar[/"Mostrar maximo"/]
#     fin([Fin])
#
#     inicio --> leer1 --> leer2 --> decision
#     decision -->|Verdadero| asignar_a --> mostrar
#     decision -->|Falso| asignar_b --> mostrar
#     mostrar --> fin
#
#     style inicio fill:#e8f4f8,stroke:#3498db,stroke-width:3px
#     style fin fill:#e8f4f8,stroke:#3498db,stroke-width:3px
#     style leer1 fill:#fef5e7,stroke:#f39c12,stroke-width:2px
#     style leer2 fill:#fef5e7,stroke:#f39c12,stroke-width:2px
#     style mostrar fill:#fef5e7,stroke:#f39c12,stroke-width:2px
#     style decision fill:#fadbd8,stroke:#e74c3c,stroke-width:2px
#     style asignar_a fill:#d5e8f7,stroke:#2980b9,stroke-width:2px
#     style asignar_b fill:#d5e8f7,stroke:#2980b9,stroke-width:2px
# ```
#
# **Ejemplo de ejecución:**
# ```
# Ingresá el primer número: 15
# Ingresá el segundo número: 23
# El máximo es: 23
# ```

# %%
# Escribí tu código aquí

# %% [markdown]
# ## Ejercicio 5: Contador del 1 al 5
#
# Implementá el siguiente algoritmo que cuenta del 1 al 5:
#
# ```mermaid
# %%{init: {'theme':'base', 'themeVariables': { 'primaryColor':'#e8f4f8','primaryTextColor':'#000','primaryBorderColor':'#3498db','lineColor':'#2c3e50','secondaryColor':'#ecf0f1','tertiaryColor':'#fff'}}}%%
# flowchart TD
#     inicio([Inicio])
#     inicializar["contador ← 1"]
#     condicion{"contador ≤ 5"}
#     mostrar[/"Mostrar contador"/]
#     incrementar["contador ← contador + 1"]
#     fin([Fin])
#
#     inicio --> inicializar --> condicion
#     condicion -->|Verdadero| mostrar --> incrementar --> condicion
#     condicion -->|Falso| fin
#
#     style inicio fill:#e8f4f8,stroke:#3498db,stroke-width:3px
#     style fin fill:#e8f4f8,stroke:#3498db,stroke-width:3px
#     style mostrar fill:#fef5e7,stroke:#f39c12,stroke-width:2px
#     style condicion fill:#fadbd8,stroke:#e74c3c,stroke-width:2px
#     style inicializar fill:#d5e8f7,stroke:#2980b9,stroke-width:2px
#     style incrementar fill:#d5e8f7,stroke:#2980b9,stroke-width:2px
# ```
#
# **Salida esperada:**
# ```
# 1
# 2
# 3
# 4
# 5
# ```

# %%
# Escribí tu código aquí

# %% [markdown]
# ## Ejercicio 6: Suma Acumulativa
#
# Implementá el siguiente algoritmo que suma números del 1 al 10:
#
# ```mermaid
# %%{init: {'theme':'base', 'themeVariables': { 'primaryColor':'#e8f4f8','primaryTextColor':'#000','primaryBorderColor':'#3498db','lineColor':'#2c3e50','secondaryColor':'#ecf0f1','tertiaryColor':'#fff'}}}%%
# flowchart TD
#     inicio([Inicio])
#     init1["suma ← 0"]
#     init2["i ← 1"]
#     condicion{"i ≤ 10"}
#     sumar["suma ← suma + i"]
#     incrementar["i ← i + 1"]
#     mostrar[/"Mostrar suma"/]
#     fin([Fin])
#
#     inicio --> init1 --> init2 --> condicion
#     condicion -->|Verdadero| sumar --> incrementar --> condicion
#     condicion -->|Falso| mostrar ---> fin
#
#     style inicio fill:#e8f4f8,stroke:#3498db,stroke-width:3px
#     style fin fill:#e8f4f8,stroke:#3498db,stroke-width:3px
#     style mostrar fill:#fef5e7,stroke:#f39c12,stroke-width:2px
#     style condicion fill:#fadbd8,stroke:#e74c3c,stroke-width:2px
#     style init1 fill:#d5e8f7,stroke:#2980b9,stroke-width:2px
#     style init2 fill:#d5e8f7,stroke:#2980b9,stroke-width:2px
#     style sumar fill:#d5e8f7,stroke:#2980b9,stroke-width:2px
#     style incrementar fill:#d5e8f7,stroke:#2980b9,stroke-width:2px
# ```
#
# **Salida esperada:**
# ```
# La suma es: 55
# ```

# %%
# Escribí tu código aquí

# %% [markdown]
# ## Ejercicio 7: Tabla de Multiplicar
#
# Implementá el siguiente algoritmo que muestra la tabla de multiplicar de un número:
#
# ```mermaid
# %%{init: {'theme':'base', 'themeVariables': { 'primaryColor':'#e8f4f8','primaryTextColor':'#000','primaryBorderColor':'#3498db','lineColor':'#2c3e50','secondaryColor':'#ecf0f1','tertiaryColor':'#fff'}}}%%
# flowchart TD
#     inicio([Inicio])
#     leer[/"Leer numero"/]
#     init["i ← 1"]
#     condicion{"i ≤ 10"}
#     calcular["resultado ← numero × i"]
#     mostrar[/"Mostrar numero, 'x', i, '=', resultado"/]
#     incrementar["i ← i + 1"]
#     fin([Fin])
#
#     inicio --> leer --> init --> condicion
#     condicion -->|Verdadero| calcular --> mostrar --> incrementar --> condicion
#     condicion ---->|Falso| fin
#
#     style inicio fill:#e8f4f8,stroke:#3498db,stroke-width:3px
#     style fin fill:#e8f4f8,stroke:#3498db,stroke-width:3px
#     style leer fill:#fef5e7,stroke:#f39c12,stroke-width:2px
#     style mostrar fill:#fef5e7,stroke:#f39c12,stroke-width:2px
#     style condicion fill:#fadbd8,stroke:#e74c3c,stroke-width:2px
#     style init fill:#d5e8f7,stroke:#2980b9,stroke-width:2px
#     style calcular fill:#d5e8f7,stroke:#2980b9,stroke-width:2px
#     style incrementar fill:#d5e8f7,stroke:#2980b9,stroke-width:2px
# ```
#
# **Ejemplo de ejecución:**
# ```
# Ingresá un número: 7
# 7 x 1 = 7
# 7 x 2 = 14
# 7 x 3 = 21
# ...
# 7 x 10 = 70
# ```

# %%
# Escribí tu código aquí

# %% [markdown]
# ## Ejercicio 8: Promedio de Números Positivos
#
# Implementá el siguiente algoritmo que calcula el promedio de números positivos ingresados (termina con 0):
#
# ```mermaid
# %%{init: {'theme':'base', 'themeVariables': { 'primaryColor':'#e8f4f8','primaryTextColor':'#000','primaryBorderColor':'#3498db','lineColor':'#2c3e50','secondaryColor':'#ecf0f1','tertiaryColor':'#fff'}}}%%
# flowchart TD
#     inicio([Inicio])
#     init1["suma ← 0"]
#     init2["contador ← 0"]
#     leer[/"Leer numero"/]
#     condicion{"numero ≠ 0"}
#     sumar["suma ← suma + numero"]
#     contar["contador ← contador + 1"]
#     calcular["promedio ← suma / contador"]
#     mostrar[/"Mostrar promedio"/]
#     fin([Fin])
#
#     inicio --> init1 --> init2 --> leer --> condicion
#     condicion -->|Verdadero| sumar --> contar --> leer
#     condicion -->|Falso| calcular --> mostrar --> fin
#
#     style inicio fill:#e8f4f8,stroke:#3498db,stroke-width:3px
#     style fin fill:#e8f4f8,stroke:#3498db,stroke-width:3px
#     style leer fill:#fef5e7,stroke:#f39c12,stroke-width:2px
#     style mostrar fill:#fef5e7,stroke:#f39c12,stroke-width:2px
#     style condicion fill:#fadbd8,stroke:#e74c3c,stroke-width:2px
#     style init1 fill:#d5e8f7,stroke:#2980b9,stroke-width:2px
#     style init2 fill:#d5e8f7,stroke:#2980b9,stroke-width:2px
#     style sumar fill:#d5e8f7,stroke:#2980b9,stroke-width:2px
#     style contar fill:#d5e8f7,stroke:#2980b9,stroke-width:2px
#     style calcular fill:#d5e8f7,stroke:#2980b9,stroke-width:2px
# ```
#
# **Ejemplo de ejecución:**
# ```
# Ingresá un número (0 para terminar): 10
# Ingresá un número (0 para terminar): 20
# Ingresá un número (0 para terminar): 30
# Ingresá un número (0 para terminar): 0
# El promedio es: 20.0
# ```

# %%
# Escribí tu código aquí

# %% [markdown]
# ## Ejercicio 9: Factorial
#
# Implementá el siguiente algoritmo que calcula el factorial de un número:
#
# ```mermaid
# %%{init: {'theme':'base', 'themeVariables': { 'primaryColor':'#e8f4f8','primaryTextColor':'#000','primaryBorderColor':'#3498db','lineColor':'#2c3e50','secondaryColor':'#ecf0f1','tertiaryColor':'#fff'}}}%%
# flowchart TD
#     inicio([Inicio])
#     leer[/"Leer n"/]
#     init1["factorial ← 1"]
#     init2["i ← 1"]
#     condicion{"i ≤ n"}
#     multiplicar["factorial ← factorial × i"]
#     incrementar["i ← i + 1"]
#     mostrar[/"Mostrar factorial"/]
#     fin([Fin])
#
#     inicio --> leer --> init1 --> init2 --> condicion
#     condicion -->|Verdadero| multiplicar --> incrementar --> condicion
#     condicion -->|Falso| mostrar --> fin
#
#     style inicio fill:#e8f4f8,stroke:#3498db,stroke-width:3px
#     style fin fill:#e8f4f8,stroke:#3498db,stroke-width:3px
#     style leer fill:#fef5e7,stroke:#f39c12,stroke-width:2px
#     style mostrar fill:#fef5e7,stroke:#f39c12,stroke-width:2px
#     style condicion fill:#fadbd8,stroke:#e74c3c,stroke-width:2px
#     style init1 fill:#d5e8f7,stroke:#2980b9,stroke-width:2px
#     style init2 fill:#d5e8f7,stroke:#2980b9,stroke-width:2px
#     style multiplicar fill:#d5e8f7,stroke:#2980b9,stroke-width:2px
#     style incrementar fill:#d5e8f7,stroke:#2980b9,stroke-width:2px
# ```
#
# **Ejemplo de ejecución:**
# ```
# Ingresá un número: 5
# El factorial de 5 es: 120
# ```
#
# **Recordá:** 5! = 5 × 4 × 3 × 2 × 1 = 120

# %%
# Escribí tu código aquí

# %% [markdown]
# ## Ejercicio 10: Adivinar el Número
#
# Implementá el siguiente algoritmo de un juego donde el usuario debe adivinar un número secreto:
#
# ```mermaid
# %%{init: {'theme':'base', 'themeVariables': { 'primaryColor':'#e8f4f8','primaryTextColor':'#000','primaryBorderColor':'#3498db','lineColor':'#2c3e50','secondaryColor':'#ecf0f1','tertiaryColor':'#fff'}}}%%
# flowchart TD
#     inicio([Inicio])
#     init["secreto ← 42"]
#     leer[/"Leer intento"/]
#     decision{"intento = secreto"}
#     correcto[/"Mostrar '¡Correcto!'"/]
#     verificar{"intento < secreto"}
#     mayor[/"Mostrar 'Muy alto'"/]
#     menor[/"Mostrar 'Muy bajo'"/]
#     fin([Fin])
#
#     inicio --> init --> leer --> decision
#     decision -->|Verdadero| correcto ---> fin
#     decision -->|Falso| verificar
#     verificar --->|Falso| mayor --> leer
#     verificar -->|Verdadero| menor --> leer
#
#     style inicio fill:#e8f4f8,stroke:#3498db,stroke-width:3px
#     style fin fill:#e8f4f8,stroke:#3498db,stroke-width:3px
#     style leer fill:#fef5e7,stroke:#f39c12,stroke-width:2px
#     style correcto fill:#fef5e7,stroke:#f39c12,stroke-width:2px
#     style menor fill:#fef5e7,stroke:#f39c12,stroke-width:2px
#     style mayor fill:#fef5e7,stroke:#f39c12,stroke-width:2px
#     style decision fill:#fadbd8,stroke:#e74c3c,stroke-width:2px
#     style verificar fill:#fadbd8,stroke:#e74c3c,stroke-width:2px
#     style init fill:#d5e8f7,stroke:#2980b9,stroke-width:2px
# ```
#
# **Ejemplo de ejecución:**
# ```
# Adiviná el número: 30
# Muy bajo
# Adiviná el número: 50
# Muy alto
# Adiviná el número: 42
# ¡Correcto!
# ```

# %%
# Escribí tu código aquí

# %% [markdown]
# ---
#
# ## ¡Felicitaciones!
#
# Has completado los ejercicios de diagramas de flujo. Estos ejercicios te ayudaron a:
#
# - Interpretar diagramas de flujo
# - Comprender la lógica de secuencias, decisiones y lazos
# - Traducir algoritmos visuales a código Python
# - Practicar con variables, operaciones y control de flujo
#
# Seguí practicando con más ejercicios en los otros cuadernos disponibles.
