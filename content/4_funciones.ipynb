# %% [markdown]
# # Funciones en Python - Ejercicios
#
# Este cuaderno contiene ejercicios prácticos para complementar el capítulo 4: [Funciones](https://ingcom-unrn.github.io/apunte-ingreso/funciones/).
#
# Si estás muy perdido en cómo usar esta herramienta, consultá con la [Guía Jupyterlab](https://ingcom-unrn.github.io/apunte-ingreso/jupyterlab/) o hacé una pregunta.
#
# Pueden modificar todo, por lo que son libres de practicar como se les ocurra ;-)
#
# ## Temas a practicar
#
# 1. **Definir y llamar funciones** - Sintaxis básica
# 2. **Parámetros y argumentos** - Posicionales, keyword, múltiples
# 3. **Return** - Retornar valores
# 4. **Scope** - Alcance de variables
# 5. **Parámetros por defecto** - Valores opcionales
# 6. **Documentación** - Docstrings
# 7. **Descomposición funcional** - Dividir problemas
# 8. **Solución de problemas** - 10 ejercicios desafiantes
#
# ---

# %% [markdown]
# ## 1. Definir y Llamar Funciones

# %% [markdown]
# ### Ejercicio 1.1: Tu primera función
#
# **Problema:** Creá una función llamada `saludar()` que imprima "¡Hola, mundo!" cuando se la llame.

# %%
def saludar():
    # Tu código aquí
    pass

# Prueba
saludar()

# %% [markdown]
# ### Ejercicio 1.2: Función con parámetro
#
# **Problema:** Creá una función `saludar_persona(nombre)` que reciba un nombre y salude a esa persona.

# %%
def saludar_persona(nombre):
    # Tu código aquí
    pass

# Pruebas
saludar_persona("Ana")
saludar_persona("Carlos")

# %% [markdown]
# ### Ejercicio 1.3: Función con múltiples parámetros
#
# **Problema:** Creá una función `presentar(nombre, edad, ciudad)` que presente a una persona.

# %%
def presentar(nombre, edad, ciudad):
    # Tu código aquí
    pass

# Pruebas
presentar("Ana", 25, "Bariloche")

# %% [markdown]
# ### Ejercicio 1.4: Función que llama a otra
#
# **Problema:** Creá dos funciones: `obtener_saludo()` que retorne "¡Hola!" y `saludar_completo(nombre)` que use la primera.

# %%
def obtener_saludo():
    # Tu código aquí
    pass

def saludar_completo(nombre):
    # Tu código aquí
    pass

# Pruebas
print(saludar_completo("Ana"))

# %% [markdown]
# ### Ejercicio 1.5: Múltiples llamadas
#
# **Problema:** Creá una función `cuadrado(n)` que retorne el cuadrado de un número. Llamala 5 veces con diferentes valores y guardá los resultados en una lista.

# %%
def cuadrado(n):
    # Tu código aquí
    pass

# Tu código aquí para crear la lista
resultados = []

print(f"Cuadrados: {resultados}")

# %% [markdown]
# ## 2. Parámetros y Argumentos

# %% [markdown]
# ### Ejercicio 2.1: Argumentos posicionales
#
# **Problema:** Creá una función `calcular_rectangulo(base, altura)` que calcule área y perímetro de un rectángulo. Retorná ambos valores como tupla.

# %%
def calcular_rectangulo(base, altura):
    # Tu código aquí
    pass

# Pruebas
area, perimetro = calcular_rectangulo(5, 3)
print(f"Área: {area}, Perímetro: {perimetro}")

# %% [markdown]
# ### Ejercicio 2.2: Argumentos con nombre
#
# **Problema:** Creá una función `crear_perfil(nombre, edad, ciudad, profesion)`. Llamala usando argumentos con nombre en diferente orden.

# %%
def crear_perfil(nombre, edad, ciudad, profesion):
    # Tu código aquí
    pass

# Llamadas con argumentos con nombre
perfil1 = crear_perfil(edad=25, nombre="Ana", profesion="Ingeniera", ciudad="Bariloche")
print(perfil1)

# %% [markdown]
# ### Ejercicio 2.3: Mezclar posicionales y keyword
#
# **Problema:** Creá una función `registrar_compra(producto, cantidad, precio, descuento)` donde los primeros dos sean posicionales obligatorios y los otros dos sean keyword.

# %%
def registrar_compra(producto, cantidad, precio, descuento):
    # Tu código aquí
    pass

# Pruebas
registrar_compra("Laptop", 1, precio=1500, descuento=0.1)
registrar_compra("Mouse", 2, precio=25, descuento=0)

# %% [markdown]
# ### Ejercicio 2.4: Validar parámetros
#
# **Problema:** Creá una función `dividir(a, b)` que valide que b no sea cero antes de dividir. Si es cero, retorná un mensaje de error.

# %%
def dividir(a, b):
    # Tu código aquí
    pass

# Pruebas
print(dividir(10, 2))   # 5.0
print(dividir(10, 0))   # Error: no se puede dividir por cero

# %% [markdown]
# ### Ejercicio 2.5: Parámetros variables
#
# **Problema:** Experimentá llamando a esta función con diferente cantidad de argumentos y observá qué pasa.

# %%
def sumar_numeros(a, b, c=0, d=0):
    return a + b + c + d

# Pruebas
print(sumar_numeros(1, 2))          # ¿Qué imprime?
print(sumar_numeros(1, 2, 3))       # ¿Qué imprime?
print(sumar_numeros(1, 2, 3, 4))    # ¿Qué imprime?

# %% [markdown]
# ---
#
# ## 3. Retornar Valores con `return`

# %% [markdown]
# ### Ejercicio 3.1: Return simple
#
# **Problema:** Creá una función `sumar(a, b)` que retorne la suma de dos números.

# %%
def sumar(a, b):
    # Tu código aquí
    pass

# Pruebas
resultado = sumar(5, 3)
print(f"Resultado: {resultado}")

# %% [markdown]
# ### Ejercicio 3.2: Return múltiple
#
# **Problema:** Creá una función `estadisticas(numeros)` que retorne el mínimo, máximo y promedio de una lista.

# %%
def estadisticas(numeros):
    # Tu código aquí
    pass

# Pruebas
min_val, max_val, prom = estadisticas([1, 2, 3, 4, 5])
print(f"Mín: {min_val}, Máx: {max_val}, Promedio: {prom}")

# %% [markdown]
# ### Ejercicio 3.3: Return con condicional
#
# **Problema:** Creá una función `es_par(n)` que retorne `True` si el número es par, `False` si no.

# %%
def es_par(n):
    # Tu código aquí
    pass

# Pruebas
print(es_par(4))   # True
print(es_par(7))   # False

# %% [markdown]
# ### Ejercicio 3.4: Return temprano
#
# **Problema:** Creá una función `validar_edad(edad)` que retorne "Válido" si la edad está entre 0 y 120, sino retorne "Inválido" (usá return temprano).

# %%
def validar_edad(edad):
    # Tu código aquí
    pass

# Pruebas
print(validar_edad(25))    # Válido
print(validar_edad(-5))    # Inválido
print(validar_edad(150))   # Inválido

# %% [markdown]
# ### Ejercicio 3.5: Return None implícito
#
# **Problema:** Analizá qué retorna esta función cuando no encuentra el elemento:

# %%
def buscar_elemento(lista, elemento):
    for item in lista:
        if item == elemento:
            return True
    # ¿Qué retorna si no lo encuentra?

# Pruebas
print(buscar_elemento([1, 2, 3], 2))   # ¿?
print(buscar_elemento([1, 2, 3], 5))   # ¿?

# %% [markdown]
# ---
#
# ## 4. Scope de Variables (Alcance)

# %% [markdown]
# ### Ejercicio 4.1: Variable local
#
# **Problema:** Creá una función `calcular_doble(n)` que use una variable local `resultado` para guardar el doble de n. Luego intentá imprimir `resultado` fuera de la función. ¿Qué pasa?

# %%
def calcular_doble(n):
    resultado = n * 2
    return resultado

valor = calcular_doble(5)
print(f"Valor: {valor}")
# Descomentá la siguiente línea y observá el error:
# print(resultado)

# %% [markdown]
# ### Ejercicio 4.2: Variable global
#
# **Problema:** Creá una variable global `contador = 0` y una función `incrementar()` que intente incrementarla. ¿Funciona? ¿Por qué?

# %%
contador = 0

def incrementar():
    # Tu código aquí
    pass

increment ar()
print(f"Contador: {contador}")

# %% [markdown]
# ### Ejercicio 4.3: Usar global correctamente
#
# **Problema:** Arreglá el ejercicio anterior usando `global` para modificar el contador.

# %%
contador = 0

def incrementar():
    # Tu código aquí (usá global)
    pass

increment ar()
increment ar()
increment ar()
print(f"Contador: {contador}")

# %% [markdown]
# ### Ejercicio 4.4: Shadowing
#
# **Problema:** Analizá este código. ¿Qué valores se imprimen y por qué?

# %%
x = 10

def funcion():
    x = 20
    print(f"Dentro: {x}")

funcion()
print(f"Fuera: {x}")

# %% [markdown]
# ### Ejercicio 4.5: Constantes globales
#
# **Problema:** Creá constantes globales `PI` y `E` y una función `calcular_circulo(radio)` que las use para calcular área y circunferencia.

# %%
# Constantes (por convención en MAYÚSCULAS)
PI = 3.14159
E = 2.71828

def calcular_circulo(radio):
    # Tu código aquí
    pass

# Pruebas
area, circunf = calcular_circulo(5)
print(f"Área: {area:.2f}, Circunferencia: {circunf:.2f}")

# %% [markdown]
# ---
#
# ## 5. Parámetros por Defecto

# %% [markdown]
# ### Ejercicio 5.1: Parámetro opcional simple
#
# **Problema:** Creá una función `saludar(nombre, idioma="español")` que salude en diferentes idiomas. Por defecto, español.

# %%
def saludar(nombre, idioma="español"):
    # Tu código aquí
    pass

# Pruebas
saludar("Ana")                    # Usa default
saludar("John", "inglés")         # Especifica idioma

# %% [markdown]
# ### Ejercicio 5.2: Múltiples parámetros opcionales
#
# **Problema:** Creá una función `crear_usuario(nombre, edad=18, ciudad="Desconocida", activo=True)` con varios parámetros opcionales.

# %%
def crear_usuario(nombre, edad=18, ciudad="Desconocida", activo=True):
    # Tu código aquí
    pass

# Pruebas
crear_usuario("Ana")
crear_usuario("Bruno", edad=25, ciudad="Bariloche")

# %% [markdown]
# ### Ejercicio 5.3: Calcular con descuento opcional
#
# **Problema:** Creá una función `calcular_precio(precio_base, descuento=0)` que calcule el precio final.

# %%
def calcular_precio(precio_base, descuento=0):
    # Tu código aquí
    pass

# Pruebas
print(calcular_precio(100))           # Sin descuento
print(calcular_precio(100, 0.2))      # 20% descuento

# %% [markdown]
# ### Ejercicio 5.4: Orden de parámetros
#
# **Problema:** Intentá definir esta función. ¿Por qué da error? Arreglala.

# %%
# ❌ Esta definición está mal
# def funcion_mal(a=10, b, c=20):
#     pass

# ✓ Arreglá el orden aquí
def funcion_bien():
    # Tu código aquí
    pass

# %% [markdown]
# ### Ejercicio 5.5: Peligro: lista mutable como default
#
# **Problema:** Analizá este código y explicá por qué el comportamiento es inesperado:

# %%
def agregar_item(item, lista=[]):
    lista.append(item)
    return lista

print(agregar_item(1))     # [1]
print(agregar_item(2))     # ¿[2] o [1, 2]?
print(agregar_item(3))     # ¿?

# ¿Cómo arreglarías esto?

# %% [markdown]
# ---
#
# ## 6. Documentación (Docstrings)

# %% [markdown]
# ### Ejercicio 6.1: Docstring básico
#
# **Problema:** Agregá un docstring a esta función:

# %%
def calcular_area_circulo(radio):
    # Agregá docstring aquí
    return 3.14159 * radio ** 2

# Verificá el docstring
print(calcular_area_circulo.__doc__)

# %% [markdown]
# ### Ejercicio 6.2: Docstring completo
#
# **Problema:** Completá el docstring con Args y Returns:

# %%
def dividir_entero(dividendo, divisor):
    """
    # Completá aquí
    
    Args:
        # ...
    
    Returns:
        # ...
    """
    cociente = dividendo // divisor
    resto = dividendo % divisor
    return cociente, resto

# %% [markdown]
# ### Ejercicio 6.3: Docstring con ejemplos
#
# **Problema:** Agregá ejemplos de uso en el docstring:

# %%
def factorial(n):
    """
    Calcula el factorial de un número.
    
    # Agregá ejemplos aquí
    Examples:
        >>> factorial(5)
        120
    """
    if n == 0 or n == 1:
        return 1
    return n * factorial(n - 1)

# %% [markdown]
# ### Ejercicio 6.4: Leer docstrings
#
# **Problema:** Usá `help()` para leer el docstring de funciones built-in:

# %%
# Descomentá y ejecutá:
# help(len)
# help(sum)
# help(max)

# ¿Qué información proveen los docstrings?

# %% [markdown]
# ### Ejercicio 6.5: Tu propia función documentada
#
# **Problema:** Creá una función `es_primo(n)` completamente documentada con docstring, que determine si un número es primo.

# %%
def es_primo(n):
    """
    # Tu docstring completo aquí
    """
    # Tu código aquí
    pass

# Pruebas
print(es_primo(7))    # True
print(es_primo(10))   # False

# %% [markdown]
# ---
#
# ## 7. Descomposición Funcional

# %% [markdown]
# ### Ejercicio 7.1: Identificar funciones necesarias
#
# **Problema:** Dado este código monolítico, identificá qué funciones crearías:
#
# ```python
# def procesar_estudiante():
#     nombre = input("Nombre: ")
#     nota1 = float(input("Nota 1: "))
#     nota2 = float(input("Nota 2: "))
#     nota3 = float(input("Nota 3: "))
#     promedio = (nota1 + nota2 + nota3) / 3
#     if promedio >= 6:
#         estado = "Aprobado"
#     else:
#         estado = "Desaprobado"
#     print(f"{nombre}: {promedio:.2f} - {estado}")
# ```
#
# Listá al menos 4 funciones que crearías:

# %%
# Tu análisis aquí:
# 1. 
# 2. 
# 3. 
# 4.

# %% [markdown]
# ### Ejercicio 7.2: Descomponer calculadora de IMC
#
# **Problema:** Descomponé este problema en funciones:
# - Pedir peso y altura
# - Calcular IMC
# - Clasificar IMC (bajo peso, normal, sobrepeso, obesidad)
# - Mostrar resultado
#
# Implementá las 4 funciones:

# %%
def pedir_peso():
    # Tu código aquí
    pass

def pedir_altura():
    # Tu código aquí
    pass

def calcular_imc(peso, altura):
    # Tu código aquí
    pass

def clasificar_imc(imc):
    # Tu código aquí
    pass

def mostrar_resultado(peso, altura, imc, clasificacion):
    # Tu código aquí
    pass

# Función principal que orquesta todo
def main():
    # Tu código aquí
    pass

# main()

# %% [markdown]
# ### Ejercicio 7.3: Validador de contraseñas modular
#
# **Problema:** Descomponé la validación de contraseñas en funciones pequeñas:
# - `tiene_mayuscula(password)` → bool
# - `tiene_minuscula(password)` → bool
# - `tiene_numero(password)` → bool
# - `tiene_longitud_minima(password, min=8)` → bool
# - `validar_password(password)` → (bool, str)

# %%
def tiene_mayuscula(password):
    # Tu código aquí
    pass

def tiene_minuscula(password):
    # Tu código aquí
    pass

def tiene_numero(password):
    # Tu código aquí
    pass

def tiene_longitud_minima(password, minimo=8):
    # Tu código aquí
    pass

def validar_password(password):
    # Tu código aquí usando las funciones anteriores
    pass

# Pruebas
print(validar_password("Hola123"))    # (True, "Válida")
print(validar_password("hola"))       # (False, "Errores...")

# %% [markdown]
# ### Ejercicio 7.4: Sistema de descuentos modular
#
# **Problema:** Creá un sistema de descuentos descompuesto:
# - `calcular_descuento_cantidad(cantidad)` → float
# - `calcular_descuento_cliente(es_vip)` → float
# - `calcular_descuento_temporada(mes)` → float
# - `calcular_precio_final(precio, cantidad, es_vip, mes)` → float

# %%
def calcular_descuento_cantidad(cantidad):
    """
    >10 items: 10% descuento
    >50 items: 20% descuento
    """
    # Tu código aquí
    pass

def calcular_descuento_cliente(es_vip):
    """VIP: 15% descuento"""
    # Tu código aquí
    pass

def calcular_descuento_temporada(mes):
    """Julio: 10% descuento"""
    # Tu código aquí
    pass

def calcular_precio_final(precio_base, cantidad, es_vip=False, mes=1):
    """Calcula precio final aplicando todos los descuentos"""
    # Tu código aquí
    pass

# Pruebas
print(calcular_precio_final(100, 5))                    # Sin descuentos
print(calcular_precio_final(100, 15, es_vip=True))      # Con descuentos

# %% [markdown]
# ### Ejercicio 7.5: Diseño completo - Sistema de tareas
#
# **Problema:** Diseñá (no implementes todavía) un sistema de gestión de tareas:
# - Listar funciones necesarias
# - Definir parámetros de cada una
# - Definir qué retorna cada una
# - Identificar niveles de abstracción

# %%
# Tu diseño aquí:
# 
# === NIVEL BAJO (operaciones básicas) ===
# def crear_tarea(descripcion, prioridad="normal") -> dict:
#     ...
#
# === NIVEL MEDIO (operaciones compuestas) ===
# def buscar_tareas_pendientes(tareas) -> list:
#     ...
#
# === NIVEL ALTO (orquestación) ===
# def main():
#     ...

# %% [markdown]
# ---
#
# ## 8. Solución de Problemas - Desafíos
#
# Esta sección contiene 10 ejercicios desafiantes que integran múltiples conceptos.

# %% [markdown]
# ### Problema 1: Conversor de temperatura
#
# **Problema:** Creá funciones para convertir entre Celsius, Fahrenheit y Kelvin. Debe haber una función principal que convierta entre cualquier par de escalas.
#
# ```python
# # Funciones de conversión directa
# def celsius_a_fahrenheit(c) -> float
# def celsius_a_kelvin(c) -> float
# def fahrenheit_a_celsius(f) -> float
# # ... (6 funciones en total)
#
# # Función principal
# def convertir_temperatura(valor, escala_origen, escala_destino) -> float
# ```

# %%
def celsius_a_fahrenheit(c):
    # Tu código aquí
    pass

def celsius_a_kelvin(c):
    # Tu código aquí
    pass

def fahrenheit_a_celsius(f):
    # Tu código aquí
    pass

def fahrenheit_a_kelvin(f):
    # Tu código aquí
    pass

def kelvin_a_celsius(k):
    # Tu código aquí
    pass

def kelvin_a_fahrenheit(k):
    # Tu código aquí
    pass

def convertir_temperatura(valor, origen, destino):
    """
    Convierte temperatura entre escalas.
    
    Args:
        valor: Temperatura a convertir
        origen: 'C', 'F' o 'K'
        destino: 'C', 'F' o 'K'
    
    Returns:
        Temperatura convertida
    """
    # Tu código aquí
    pass

# Pruebas
print(convertir_temperatura(0, 'C', 'F'))      # 32
print(convertir_temperatura(100, 'C', 'K'))    # 373.15

# %% [markdown]
# ### Problema 2: Calculadora estadística
#
# **Problema:** Creá una calculadora estadística completa:
# - `calcular_media(datos)` → float
# - `calcular_mediana(datos)` → float
# - `calcular_moda(datos)` → valor más frecuente
# - `calcular_rango(datos)` → tuple (min, max)
# - `calcular_desviacion(datos)` → float
# - `reporte_completo(datos)` → dict con todas las estadísticas

# %%
def calcular_media(datos):
    # Tu código aquí
    pass

def calcular_mediana(datos):
    # Tu código aquí
    pass

def calcular_moda(datos):
    # Tu código aquí
    pass

def calcular_rango(datos):
    # Tu código aquí
    pass

def calcular_desviacion(datos):
    # Tu código aquí
    pass

def reporte_completo(datos):
    # Tu código aquí usando todas las funciones anteriores
    pass

# Pruebas
datos = [1, 2, 2, 3, 4, 5, 5, 5, 6]
reporte = reporte_completo(datos)
print(reporte)

# %% [markdown]
# ### Problema 3: Generador de contraseñas
#
# **Problema:** Creá un generador de contraseñas seguras:
# - `generar_password(longitud, incluir_mayus=True, incluir_nums=True, incluir_especiales=True)` → str
# - `validar_fortaleza(password)` → (int, str) donde int es 1-5 y str es descripción

# %%
import random
import string

def generar_password(longitud, incluir_mayus=True, incluir_nums=True, incluir_especiales=True):
    """
    Genera contraseña aleatoria.
    
    Args:
        longitud: Longitud de la contraseña
        incluir_mayus: Incluir mayúsculas
        incluir_nums: Incluir números
        incluir_especiales: Incluir caracteres especiales
    
    Returns:
        Contraseña generada
    """
    # Tu código aquí
    pass

def validar_fortaleza(password):
    """
    Evalúa fortaleza de contraseña.
    
    Returns:
        (nivel, descripcion) donde nivel es 1-5
    """
    # Tu código aquí
    pass

# Pruebas
password = generar_password(12)
print(f"Password: {password}")
nivel, desc = validar_fortaleza(password)
print(f"Fortaleza: {nivel}/5 - {desc}")

# %% [markdown]
# ### Problema 4: Analizador de texto
#
# **Problema:** Creá un analizador de texto completo:
# - `contar_palabras(texto)` → int
# - `contar_caracteres(texto, incluir_espacios=True)` → int
# - `palabra_mas_larga(texto)` → str
# - `frecuencia_palabras(texto)` → dict
# - `analisis_completo(texto)` → dict con todos los análisis

# %%
def contar_palabras(texto):
    # Tu código aquí
    pass

def contar_caracteres(texto, incluir_espacios=True):
    # Tu código aquí
    pass

def palabra_mas_larga(texto):
    # Tu código aquí
    pass

def frecuencia_palabras(texto):
    # Tu código aquí
    pass

def analisis_completo(texto):
    # Tu código aquí
    pass

# Pruebas
texto = "Python es un lenguaje de programación. Python es poderoso."
analisis = analisis_completo(texto)
print(analisis)

# %% [markdown]
# ### Problema 5: Sistema de calificaciones
#
# **Problema:** Implementá un sistema completo de calificaciones:
# - `calcular_promedio(notas)` → float
# - `nota_letra(promedio)` → str (A, B, C, D, F)
# - `necesita_recuperatorio(notas)` → bool
# - `calcular_nota_necesaria_recup(promedio_actual)` → float
# - `generar_boletin(nombre, notas)` → str formateado

# %%
def calcular_promedio(notas):
    # Tu código aquí
    pass

def nota_letra(promedio):
    """A:9-10, B:7-8.9, C:6-6.9, D:4-5.9, F:<4"""
    # Tu código aquí
    pass

def necesita_recuperatorio(notas):
    """True si promedio < 6"""
    # Tu código aquí
    pass

def calcular_nota_necesaria_recup(promedio_actual, nota_minima=6):
    """Calcula qué nota necesita en recuperatorio"""
    # Tu código aquí
    pass

def generar_boletin(nombre, notas):
    """Genera reporte completo formateado"""
    # Tu código aquí
    pass

# Pruebas
boletin = generar_boletin("Ana García", [7, 8, 6])
print(boletin)

# %% [markdown]
# ### Problema 6: Conversor de bases numéricas
#
# **Problema:** Creá conversores entre diferentes bases:
# - `decimal_a_binario(n)` → str
# - `decimal_a_hexadecimal(n)` → str
# - `binario_a_decimal(bin_str)` → int
# - `hexadecimal_a_decimal(hex_str)` → int
# - `convertir_base(valor, base_origen, base_destino)` → str

# %%
def decimal_a_binario(n):
    # Tu código aquí
    pass

def decimal_a_hexadecimal(n):
    # Tu código aquí
    pass

def binario_a_decimal(bin_str):
    # Tu código aquí
    pass

def hexadecimal_a_decimal(hex_str):
    # Tu código aquí
    pass

def convertir_base(valor, origen, destino):
    """
    Convierte entre bases.
    
    Args:
        valor: Número como string
        origen: Base origen (2, 10, 16)
        destino: Base destino (2, 10, 16)
    """
    # Tu código aquí
    pass

# Pruebas
print(convertir_base("42", 10, 2))      # "101010"
print(convertir_base("101010", 2, 16))  # "2A"

# %% [markdown]
# ### Problema 7: Juego de adivinanza mejorado
#
# **Problema:** Creá un juego de adivinanza de números con funciones:
# - `generar_numero_secreto(min, max)` → int
# - `pedir_intento()` → int
# - `evaluar_intento(secreto, intento)` → str ("mayor", "menor", "correcto")
# - `calcular_puntaje(intentos, max_intentos)` → int
# - `jugar()` → orquesta todo el juego

# %%
import random

def generar_numero_secreto(minimo=1, maximo=100):
    # Tu código aquí
    pass

def pedir_intento():
    # Tu código aquí con validación
    pass

def evaluar_intento(secreto, intento):
    # Tu código aquí
    pass

def calcular_puntaje(intentos, max_intentos=10):
    """Más puntos si adivina rápido"""
    # Tu código aquí
    pass

def jugar():
    """Función principal del juego"""
    # Tu código aquí
    pass

# jugar()

# %% [markdown]
# ### Problema 8: Validador de formulario
#
# **Problema:** Creá validadores para un formulario:
# - `validar_email(email)` → (bool, str)
# - `validar_telefono(tel)` → (bool, str)
# - `validar_edad(edad)` → (bool, str)
# - `validar_nombre(nombre)` → (bool, str)
# - `validar_formulario(datos)` → (bool, list_errores)

# %%
def validar_email(email):
    """Debe contener @ y un dominio"""
    # Tu código aquí
    pass

def validar_telefono(tel):
    """Debe tener 10 dígitos"""
    # Tu código aquí
    pass

def validar_edad(edad):
    """Entre 0 y 120"""
    # Tu código aquí
    pass

def validar_nombre(nombre):
    """Mínimo 2 caracteres, solo letras"""
    # Tu código aquí
    pass

def validar_formulario(datos):
    """
    Valida diccionario completo.
    
    Args:
        datos: dict con 'nombre', 'edad', 'email', 'telefono'
    
    Returns:
        (es_valido, lista_errores)
    """
    # Tu código aquí
    pass

# Pruebas
formulario = {
    "nombre": "Ana García",
    "edad": 25,
    "email": "ana@example.com",
    "telefono": "1234567890"
}
valido, errores = validar_formulario(formulario)
print(f"Válido: {valido}")
if errores:
    print("Errores:", errores)

# %% [markdown]
# ### Problema 9: Sistema de inventario
#
# **Problema:** Creá un sistema de inventario modular:
# - `agregar_producto(inventario, nombre, cantidad, precio)` → None
# - `eliminar_producto(inventario, nombre)` → bool
# - `actualizar_stock(inventario, nombre, cantidad)` → bool
# - `buscar_producto(inventario, nombre)` → dict o None
# - `calcular_valor_total(inventario)` → float
# - `productos_bajo_stock(inventario, minimo=10)` → list
# - `generar_reporte(inventario)` → str

# %%
def agregar_producto(inventario, nombre, cantidad, precio):
    # Tu código aquí
    pass

def eliminar_producto(inventario, nombre):
    # Tu código aquí
    pass

def actualizar_stock(inventario, nombre, cantidad):
    # Tu código aquí
    pass

def buscar_producto(inventario, nombre):
    # Tu código aquí
    pass

def calcular_valor_total(inventario):
    # Tu código aquí
    pass

def productos_bajo_stock(inventario, minimo=10):
    # Tu código aquí
    pass

def generar_reporte(inventario):
    # Tu código aquí
    pass

# Pruebas
inventario = {}
agregar_producto(inventario, "Laptop", 5, 1500)
agregar_producto(inventario, "Mouse", 50, 25)
print(generar_reporte(inventario))

# %% [markdown]
# ### Problema 10: Calculadora de fechas
#
# **Problema:** Creá funciones para trabajar con fechas:
# - `es_bisiesto(año)` → bool
# - `dias_en_mes(mes, año)` → int
# - `calcular_edad(dia, mes, año)` → int
# - `dias_entre_fechas(fecha1, fecha2)` → int
# - `sumar_dias(fecha, dias)` → tuple

# %%
def es_bisiesto(año):
    """Año bisiesto si es divisible por 4, excepto siglos que no son divisibles por 400"""
    # Tu código aquí
    pass

def dias_en_mes(mes, año):
    """Retorna cantidad de días en el mes"""
    # Tu código aquí
    pass

def calcular_edad(dia, mes, año):
    """Calcula edad en años"""
    from datetime import datetime
    # Tu código aquí
    pass

def dias_entre_fechas(fecha1, fecha2):
    """
    Calcula días entre dos fechas.
    
    Args:
        fecha1: tuple (dia, mes, año)
        fecha2: tuple (dia, mes, año)
    """
    # Tu código aquí
    pass

def sumar_dias(fecha, dias):
    """Suma días a una fecha"""
    # Tu código aquí
    pass

# Pruebas
print(es_bisiesto(2024))  # True
print(dias_en_mes(2, 2024))  # 29
print(calcular_edad(15, 3, 1990))

# %% [markdown]
# ---
#
# ## Resumen y Próximos Pasos
#
# ¡Felicitaciones! Has completado los ejercicios de funciones.
#
# ### Lo que practicaste:
#
# ✅ **Definir y llamar funciones**: Sintaxis básica y flujo de ejecución
# ✅ **Parámetros**: Posicionales, keyword, múltiples
# ✅ **Return**: Retornar valores simples y múltiples
# ✅ **Scope**: Variables locales, globales y constantes
# ✅ **Parámetros por defecto**: Valores opcionales
# ✅ **Documentación**: Docstrings profesionales
# ✅ **Descomposición funcional**: Dividir problemas complejos
# ✅ **Resolución de problemas**: Integración de conceptos
#
# ### Próximos pasos:
#
# 1. **Repasá** los ejercicios que te resultaron difíciles
# 2. **Experimentá** con variantes de los problemas
# 3. **Continuá** con el siguiente capítulo sobre módulos
# 4. **Practicá** la descomposición funcional en tus programas
#
# ### Recursos adicionales:
#
# - [Documentación oficial - Funciones](https://docs.python.org/3/tutorial/controlflow.html#defining-functions)
# - [Real Python - Functions](https://realpython.com/defining-your-own-python-function/)
# - [Clean Code - Functions Chapter](https://www.oreilly.com/library/view/clean-code-a/9780136083238/)
#
# ---
#
# **¡Seguí practicando! Las funciones son fundamentales en programación. 🚀🐍**
